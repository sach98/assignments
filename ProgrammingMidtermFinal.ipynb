# %% [markdown]
# # MIDTERM EXAM My first data science project

# %% [markdown]
# ## In this lab you will apply the concepts and techniques developed in sessions 1-6. You are expected to work on the assignments on your own between Tuesday the 8th at 11am and Wednesday the 9th at 11 am. We recomend hadning in an hour early to aviod any issues with traffic on the ELE.
#
# ## You are expected to submit the code developed as well as a brief description of your findings and insights for each assigment.
#
# ## You can do this by creating [markdown cells](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm#:~:text=%20Jupyter%20Notebook%20-%20Markdown%20Cells%20%201,To%20attach%20link%20to%20text%2C%20place...%20More%20) in jupyter notebook, and writting in them.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
### Let's load the gapminder dataset
gapminder = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ## QUESTIONS

# %% [markdown]
# ### (1) Use pairplot to visualise the data. Colour code data points by the continent they are from.

# %% [markdown]
# #### Answer 1:

# %%
sns.pairplot(gapminder, hue='continent', corner=True, palette="bright") 
sns.set(rc = {'figure.figsize':(20,8)})

# %% [markdown]
# ### (2) What patterns can you see? Are there any outliars?

# %% [markdown]
# ### Answer 2:

# %% [markdown]
#    ##### Patterns:
#    1. Year vs Life Expectancy:
#         * Over the years the Avg life expectancy in the world has gone.
#         * American, European & Ocieanic countries have had somewhat liner growth in life expectancy.
#    2. Year vs Population:
#         * Most countries have had a linear growth.
#         * The population of all countries has increased over the years.
#    3. Life Expectancy vs Population:
#         * Most countries have a life expectancy between 50-75.
#    4. Year vs GDP per Capita:
#         * In africa the avg GDP per Capita is the lowest throuhghout the years.
#         * America & Europe have had linear growth in GDP over the years.
#    5. Life Expectancy vs GDP per Capita:
#         * Countries with higher GDP have higher Life Expectancy.
#    6. GDP per Capita vs Population:
#        * Most of the population around the world has a GDP of less than 500.00 per cap.

# %% [markdown]
#    ##### Outliers:
#    1. Years vs Life Expectancy:
#        * Some African countries like Rwanda,Gambia,Angola & Sierra Leone are outliers as they have faced political problems throughout the years.
#    2. Years vs Population:
#        * Some Asian countries have had exponential growth over the years due to industrial revolution & globalisation in the late 1900s.
#    3. Life Expectancy vs Population
#        * We can see that there was a sudden growth in the life expectancy in Asian countries, this might have been due to changes brought to the healthcare system which brought about less infant mortality rate, better & more modern hospitals, etc.
#    4. Year vs GDP per Capita:
#        * Gulf Asian countries like Kuwait had discovered their country was rich in fossil fuel reserves which led to a sudden growth in their GDP over the years.
#    5. Life Expectancy vs GDP per Capita:
#        * As we can see Asian Countries with the most per capita income such as Kuwait are outliers. Better income leads to people being able to afford better healthcare.
#    6. GDP per Capita vs Population:
#        * Asia has the highest population with the lowest GDP per Capita.
#        * Asia also has the highest population with the highest GDP per Capita.

# %% [markdown]
# ### (3) Filter the dataset to find rows in which life GDP per capita is greater than 60,000

# %% [markdown]
# ### Answer 3:

# %%
rich=gapminder['gdpPercap']>60000

# %%
gapminder[rich]
# Out:
#     country continent  year  lifeExp     pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565  160000  108382.35290
# 853  Kuwait      Asia  1957   58.033  212846  113523.13290
# 854  Kuwait      Asia  1962   60.470  358266   95458.11176
# 855  Kuwait      Asia  1967   64.624  575003   80894.88326
# 856  Kuwait      Asia  1972   67.712  841934  109347.86700

# %% [markdown]
# ### (4) What does this tell us about the data, as seen in the question (1)  pairplot?

# %% [markdown]
# ### Answer 4:

# %% [markdown]
# ##### Kuwait is an outlier.
# * This tells us that Kuwait has the highest GDP per Capita.
# * We can also see that despite having the highest GDP per Capita in the world, the life expectancy of Kuwait's population is not even in the top 20 of the world. This tells us that there is a co-relation between the GDP per Capita vs Life Expectancy but not causation, i.e. if a country has a high GDP per capita that does not mean the Life Expectancy of the country needs to be high.
# * Kuwait has also seen a sudden growth in its population over the years. This could because of Globalisation and their discovery of oil in their land.

# %% [markdown]
# ### (5) Find the rows in the dataframe with the top 20 life expectancies

# %% [markdown]
# #### Answer 5:

# %%
top20=gapminder.sort_values(by='lifeExp',ascending=False)

# %%
top20.head(20)
# Out:
#                country continent  year  lifeExp        pop    gdpPercap
# 803              Japan      Asia  2007   82.603  127467972  31656.06806
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 802              Japan      Asia  2002   82.000  127065841  28604.59190
# 695            Iceland    Europe  2007   81.757     301931  36180.78919
# 1487       Switzerland    Europe  2007   81.701    7554661  37506.41907
# 670   Hong Kong, China      Asia  2002   81.495    6762476  30209.01516
# 71           Australia   Oceania  2007   81.235   20434176  34435.36744
# 1427             Spain    Europe  2007   80.941   40448191  28821.06370
# 1475            Sweden    Europe  2007   80.884    9031088  33859.74835
# 767             Israel      Asia  2007   80.745    6426679  25523.27710
# 801              Japan      Asia  1997   80.690  125956499  28816.58499
# 539             France    Europe  2007   80.657   61083916  30470.01670
# ...

# %% [markdown]
# ### (6) Plot the evolution of life expectancy, population and GDP per capita of Kuwait

# %% [markdown]
# #### Answer 6:

# %%
Kuwait=gapminder['country'].str.contains('Kuwait')

# %%
PopVSgdp=gapminder[Kuwait]

# %%
PopVSgdp[['country','lifeExp','gdpPercap']]
# Out:
#     country  lifeExp     gdpPercap
# 852  Kuwait   55.565  108382.35290
# 853  Kuwait   58.033  113523.13290
# 854  Kuwait   60.470   95458.11176
# 855  Kuwait   64.624   80894.88326
# 856  Kuwait   67.712  109347.86700
# 857  Kuwait   69.343   59265.47714
# 858  Kuwait   71.309   31354.03573
# 859  Kuwait   74.174   28118.42998
# 860  Kuwait   75.190   34932.91959
# 861  Kuwait   76.156   40300.61996
# 862  Kuwait   76.904   35110.10566
# 863  Kuwait   77.588   47306.98978

# %%
sns.lineplot(x='year',y='lifeExp',data=PopVSgdp, palette="bright")
sns.set(rc = {'figure.figsize':(20,8)})
plt.xlabel('Year',fontsize=14)
plt.ylabel('Life Expectancy',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %%
sns.lineplot(x='year',y='pop',data=PopVSgdp, palette="bright")
plt.xlabel('Year',fontsize=14)
plt.ylabel('Population',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %%
sns.lineplot(x='year',y='gdpPercap',data=PopVSgdp, palette="bright")
plt.xlabel('Year',fontsize=14)
plt.ylabel('GDP Per Capita',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %% [markdown]
# ### (7) Visualise the distribution of GDP per capita of countries and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# #### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# #### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# #### Answer 7:

# %%
sns.displot(gapminder, x="gdpPercap", y="lifeExp",hue='continent', palette="bright")
plt.xlabel('GDP per Capita',fontsize=14)
plt.ylabel('Life Expectancy',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %%
sns.regplot(x='gdpPercap', y='lifeExp', data=gapminder,scatter=True,fit_reg=True)
plt.xlabel('GDP per Capita',fontsize=14)
plt.ylabel('Life Expectancy',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %% [markdown]
# ### (8) Visualise the distribution of year and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# ### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# ### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# #### Answer 8:

# %%
sns.displot(gapminder, x="year", y="lifeExp",hue='year', palette="bright")
plt.xlabel('Year',fontsize=14)
plt.ylabel('Life Expectancy',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %%
sns.regplot(x='year', y='lifeExp',data=gapminder,color='deepskyblue', scatter=True, fit_reg=True)
plt.xlabel('Year',fontsize=14)
plt.ylabel('Life Expectancy',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %% [markdown]
# ### (9) Use Boxplots or violinplots to visualise the distribution of change in life expectancy from 1952 to 2007.
#
# Hint tools from lab 6 may be helpful.

# %% [markdown]
# #### Answer 9:

# %%
ax=sns.boxplot(x='year', y='lifeExp', data=gapminder, palette="bright")
ax.set_title('Boxpplot of Change in Life Expectancy',fontsize=14)
ax.set_xlabel('Year',fontsize=14)
ax.set_ylabel('Life Expectancy',fontsize=14)
plt.show()

# %% [markdown]
# ### (10) Continue this analysis of the data. Include code cells, their outputs and markdown cells where you write about your findings. What patterns can you observe in the data?

# %% [markdown]
# #### Answer 10 :

# %%
gapminder.groupby(['continent','year'])['lifeExp'].describe()
# Out:
#                 count       mean        std     min       25%      50%  \
# continent year
# Africa    1952   52.0  39.135500   5.151581  30.000  35.81175  38.8330
#           1957   52.0  41.266346   5.620123  31.570  37.43000  40.5925
#           1962   52.0  43.319442   5.875364  32.767  39.48400  42.6305
#           1967   52.0  45.334538   6.082673  34.113  41.36850  44.6985
#           1972   52.0  47.450942   6.416258  35.400  43.29800  47.0315
#           1977   52.0  49.580423   6.808197  36.788  44.51300  49.2725
#           1982   52.0  51.592865   7.375940  38.445  45.62650  50.7560
#           1987   52.0  53.344788   7.864089  39.906  46.83550  51.6395
#           1992   52.0  53.629577   9.461071  23.599  47.95450  52.4290
#           1997   52.0  53.598269   9.103387  36.087  47.30025  52.7590
#           2002   52.0  53.325231   9.586496  39.193  45.82800  51.2355
#           2007   52.0  54.806038   9.630781  39.613  47.83400  52.9265
# ...

# %%
plt.hist(gapminder.lifeExp, bins=20)
plt.xlabel('GDP per Capita', fontsize=14 )
plt.ylabel('Life Expectancy',fontsize=14)
plt.title('World Development',fontsize=14)
plt.show()

# %% [markdown]
# #### This Graph is Left Skewed.
# *This tells us that more and more people across the world are now living longer.*

# %% [markdown]
# ##### As we can see, along the years the median life expectancy has increased. This can be because of various reasons:
# * Medical technology has gotten better.
# * People are more aware for their health now.
# * Industrial Revolution has distributed wealth along the world.
# * Decreasing infant mortality rate.
# * Easier travel.
# * Easier communication.

# %% [markdown]
# #####  Lets make a scatter plot to understand better where the most populated countries in the world lie for Life Expectancy vs GDP per Capita.

# %%
plt.figure(dpi=150)
sns.scatterplot(data=gapminder,x='gdpPercap',y='lifeExp',hue='continent', sizes=(20,400), legend=True, alpha= 0.8)
plt.grid(True)
plt.xscale('log')
plt.xlabel('GDP per Capita', fontsize = 14)
plt.ylabel('Life Expectancy', fontsize = 14)
plt.title('World Development', fontsize = 20)
plt.text(1550, 67, 'India',fontsize=14)
plt.text(5650, 75, 'China',fontsize=14,)
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])
plt.show()

# %% [markdown]
# #### Inferences from the Graph :
# * We can see where the most populated countries in the world lie (between 1k - 10k).
# * We can also see that the country with the highest GDP per Capita does not have the highest Life Expectancy.
# * We can also see that most of the countries in Europe and Americas have a higher Life Expectancy than the rest of the world.
# * We can see the diversity of the population in the countries that are in Asia. The Asian population is distributed all acorss the graph.
# * We can also see that most of the African Nations have a low Life expectancy to GDP per capita Ratio.
